# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import SAC, TD3, A2C
import matplotlib.pyplot as plt
import pickle
import os
import argparse
import asyncio

# %%
models_dir = 'models'
logs_dir = 'logs'
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logs_dir):
    os.makedirs(logs_dir)

# %%
def train(env, sb3_algo, max_iters=4, model=None, curr_name=None, gamma=0.99):
    gamma_str = str(gamma).replace('.', '_')
    if model is None:
        match sb3_algo:
            case 'SAC':
                model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=f'{logs_dir}/SAC_gamma{gamma_str}')
            case 'TD3':
                model = TD3('MlpPolicy', env, verbose=1, tensorboard_log=f'{logs_dir}/TD3_gamma{gamma_str}')
            case 'A2C':
                model = A2C('MlpPolicy', env, verbose=1, tensorboard_log=f'{logs_dir}/A2C_gamma{gamma_str}')
            case _:
                print('Invalid algorithm')
                return
        name = f'{models_dir}/{sb3_algo}_gamma{gamma_str}'
    else:
        if curr_name is None:
            print('Please provide a name for the model')
            return
        name = curr_name
        model.set_env(env)

    os.makedirs(name, exist_ok=True)
    TIMESTEPS = 25000
    iters = 0
    while iters < max_iters:
        iters += 1
        model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False)
        model.save(f'{name}/{TIMESTEPS*iters}')

def test(env, sb3_algo, path_to_model):
    match sb3_algo:
        case 'SAC':
            model = SAC.load(path_to_model)
        case 'TD3':
            model = TD3.load(path_to_model)
        case 'A2C':
            model = A2C.load(path_to_model)
        case _:
            print('Invalid algorithm')
            return

    obs = env.reset()[0]
    done = False
    extra_steps = 500
    while True:
        action, _states = model.predict(obs)
        obs, _, done, _, _ = env.step(action)
        
        if done:
            extra_steps -= 1

        if extra_steps < 0:
            break

# %%
gymenv = gym.make('Humanoid-v4', render_mode=None)

# %%
train(gymenv, 'SAC', gamma=0.99)
train(gymenv, 'SAC', gamma=0.9)
train(gymenv, 'SAC', gamma=0.8)
train(gymenv, 'SAC', gamma=0.5)
train(gymenv, 'SAC', gamma=0.1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/SAC_gamma0_99/SAC_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 2700     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# /Users/szymon/miniconda3/envs/IOwADC/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 6.09GB > 5.67GB
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.6     |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 229      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 181      |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 18.6     |
# |    ent_coef        | 0.974    |
# |    ent_coef_loss   | -0.721   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 165      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 273      |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 47       |
# |    ent_coef        | 0.946    |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 172      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 141      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 380      |
# | train/             |          |
# |    actor_loss      | -35.1    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.916    |
# |    ent_coef_loss   | -2.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 279      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 134      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 464      |
# | train/             |          |
# |    actor_loss      | -38      |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | -3.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 363      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 129      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 538      |
# | train/             |          |
# |    actor_loss      | -42.3    |
# |    critic_loss     | 8.9      |
# |    ent_coef        | 0.872    |
# |    ent_coef_loss   | -3.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 437      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 126      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 611      |
# | train/             |          |
# |    actor_loss      | -44.2    |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.853    |
# |    ent_coef_loss   | -4.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 123      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 692      |
# | train/             |          |
# |    actor_loss      | -47.9    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.832    |
# |    ent_coef_loss   | -5.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 591      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 121      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 763      |
# | train/             |          |
# |    actor_loss      | -51.3    |
# |    critic_loss     | 17       |
# |    ent_coef        | 0.815    |
# |    ent_coef_loss   | -5.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 662      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 839      |
# | train/             |          |
# |    actor_loss      | -54.3    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.797    |
# |    ent_coef_loss   | -6.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 922      |
# | train/             |          |
# |    actor_loss      | -57.3    |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.777    |
# |    ent_coef_loss   | -6.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 821      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 118      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 992      |
# | train/             |          |
# |    actor_loss      | -58.5    |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.761    |
# |    ent_coef_loss   | -7.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 891      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 117      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1059     |
# | train/             |          |
# |    actor_loss      | -63.4    |
# |    critic_loss     | 8.42     |
# |    ent_coef        | 0.746    |
# |    ent_coef_loss   | -8.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 958      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 116      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1133     |
# | train/             |          |
# |    actor_loss      | -66.1    |
# |    critic_loss     | 30.5     |
# |    ent_coef        | 0.729    |
# |    ent_coef_loss   | -8.73    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1032     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 99.5     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 115      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1204     |
# | train/             |          |
# |    actor_loss      | -66.9    |
# |    critic_loss     | 25.4     |
# |    ent_coef        | 0.714    |
# |    ent_coef_loss   | -9.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1103     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 98.4     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 115      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1271     |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.7      |
# |    ent_coef_loss   | -9.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1170     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 97.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 114      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1339     |
# | train/             |          |
# |    actor_loss      | -73.1    |
# |    critic_loss     | 17       |
# |    ent_coef        | 0.686    |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1238     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | 96.6     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 114      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1405     |
# | train/             |          |
# |    actor_loss      | -76.3    |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.672    |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1304     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | 96.7     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 113      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1485     |
# | train/             |          |
# |    actor_loss      | -74.9    |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.656    |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1384     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | 96.9     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 113      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1565     |
# | train/             |          |
# |    actor_loss      | -78.4    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.641    |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1464     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | 96.7     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 113      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1639     |
# | train/             |          |
# |    actor_loss      | -80.5    |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.627    |
# |    ent_coef_loss   | -12.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1538     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 97.5     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 113      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1732     |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.61     |
# |    ent_coef_loss   | -13.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1631     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 97.5     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 113      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1810     |
# | train/             |          |
# |    actor_loss      | -85.2    |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.596    |
# |    ent_coef_loss   | -14.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1709     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | 97.8     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 112      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1893     |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | -14.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 98.5     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 111      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1985     |
# | train/             |          |
# |    actor_loss      | -89.1    |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1884     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | 98.4     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 111      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2079     |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 15.5     |
# |    ent_coef        | 0.55     |
# |    ent_coef_loss   | -16.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1978     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 99.5     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 111      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2185     |
# | train/             |          |
# |    actor_loss      | -91.3    |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2084     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 99.6     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 111      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2277     |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.519    |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2176     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 111      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2414     |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.499    |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2313     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 110      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2606     |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 88.2     |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -19.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2505     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 110      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2805     |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | -20.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2704     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 110      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 3035     |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | -21.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2934     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.7     |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 110      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 3260     |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 23.5     |
# |    ent_coef        | 0.392    |
# |    ent_coef_loss   | -22.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3159     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28       |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 110      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 3563     |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 32.9     |
# |    ent_coef        | 0.36     |
# |    ent_coef_loss   | -24.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3462     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.4     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 110      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 3783     |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 135      |
# |    ent_coef        | 0.339    |
# |    ent_coef_loss   | -25      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3682     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.2     |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 110      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 4042     |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 27.7     |
# |    ent_coef        | 0.316    |
# |    ent_coef_loss   | -25.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3941     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | 164      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 109      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4276     |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 24.4     |
# |    ent_coef        | 0.296    |
# |    ent_coef_loss   | -26.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4175     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 109      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4541     |
# | train/             |          |
# |    actor_loss      | -120     |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.276    |
# |    ent_coef_loss   | -26.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4440     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.9     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 109      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 4824     |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 31.2     |
# |    ent_coef        | 0.255    |
# |    ent_coef_loss   | -28.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4723     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.5     |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 109      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 5053     |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 30.2     |
# |    ent_coef        | 0.24     |
# |    ent_coef_loss   | -28.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4952     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.1     |
# |    ep_rew_mean     | 201      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 109      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 5283     |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 32.4     |
# |    ent_coef        | 0.225    |
# |    ent_coef_loss   | -28.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5182     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42       |
# |    ep_rew_mean     | 211      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 109      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 5544     |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.21     |
# |    ent_coef_loss   | -30.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5443     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.9     |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 109      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 5798     |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 29.9     |
# |    ent_coef        | 0.196    |
# |    ent_coef_loss   | -30.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5697     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | 234      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 109      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 6093     |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 28.4     |
# |    ent_coef        | 0.181    |
# |    ent_coef_loss   | -29.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5992     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | 242      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 109      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 6330     |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 39.1     |
# |    ent_coef        | 0.17     |
# |    ent_coef_loss   | -30      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6229     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.3     |
# |    ep_rew_mean     | 255      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 109      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 6665     |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 32.8     |
# |    ent_coef        | 0.155    |
# |    ent_coef_loss   | -31.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6564     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.9     |
# |    ep_rew_mean     | 267      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 108      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 7024     |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 42.3     |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | -31.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6923     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.1     |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 108      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 7320     |
# | train/             |          |
# |    actor_loss      | -150     |
# |    critic_loss     | 23.6     |
# |    ent_coef        | 0.13     |
# |    ent_coef_loss   | -29.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7219     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.2     |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 108      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 7610     |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 26.6     |
# |    ent_coef        | 0.121    |
# |    ent_coef_loss   | -31.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7509     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.4     |
# |    ep_rew_mean     | 298      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 108      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 7929     |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 30.7     |
# |    ent_coef        | 0.111    |
# |    ent_coef_loss   | -30.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7828     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.1     |
# |    ep_rew_mean     | 310      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 108      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 8287     |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 30.9     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -33.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8186     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.7     |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 108      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 8659     |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 50.8     |
# |    ent_coef        | 0.0925   |
# |    ent_coef_loss   | -29.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8558     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.9     |
# |    ep_rew_mean     | 334      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 108      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 8965     |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 28.9     |
# |    ent_coef        | 0.0857   |
# |    ent_coef_loss   | -26.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8864     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68.8     |
# |    ep_rew_mean     | 344      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 108      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 9292     |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 29.6     |
# |    ent_coef        | 0.0791   |
# |    ent_coef_loss   | -29.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9191     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69.9     |
# |    ep_rew_mean     | 349      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 108      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 9595     |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 38.7     |
# |    ent_coef        | 0.0734   |
# |    ent_coef_loss   | -25.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9494     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.4     |
# |    ep_rew_mean     | 352      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 108      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 9844     |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.0692   |
# |    ent_coef_loss   | -23.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9743     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.4     |
# |    ep_rew_mean     | 356      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 108      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 10178    |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 31.7     |
# |    ent_coef        | 0.064    |
# |    ent_coef_loss   | -24.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10077    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72       |
# |    ep_rew_mean     | 360      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 108      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 10465    |
# | train/             |          |
# |    actor_loss      | -152     |
# |    critic_loss     | 41.1     |
# |    ent_coef        | 0.0599   |
# |    ent_coef_loss   | -22.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10364    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.4     |
# |    ep_rew_mean     | 358      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 108      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 10707    |
# | train/             |          |
# |    actor_loss      | -152     |
# |    critic_loss     | 33.6     |
# |    ent_coef        | 0.0566   |
# |    ent_coef_loss   | -22      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10606    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.5     |
# |    ep_rew_mean     | 360      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 108      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 10935    |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 40.4     |
# |    ent_coef        | 0.0539   |
# |    ent_coef_loss   | -17.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10834    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72       |
# |    ep_rew_mean     | 364      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 108      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 11238    |
# | train/             |          |
# |    actor_loss      | -151     |
# |    critic_loss     | 42.6     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11137    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.2     |
# |    ep_rew_mean     | 366      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 108      |
# |    time_elapsed    | 106      |
# |    total_timesteps | 11501    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 43.9     |
# |    ent_coef        | 0.0478   |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.5     |
# |    ep_rew_mean     | 368      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 108      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 11791    |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 32.7     |
# |    ent_coef        | 0.0451   |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11690    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.5     |
# |    ep_rew_mean     | 369      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 108      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 12069    |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 45.6     |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | -18.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11968    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.7     |
# |    ep_rew_mean     | 371      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 108      |
# |    time_elapsed    | 114      |
# |    total_timesteps | 12327    |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 34.3     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12226    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.3     |
# |    ep_rew_mean     | 374      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 108      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 12613    |
# | train/             |          |
# |    actor_loss      | -150     |
# |    critic_loss     | 59       |
# |    ent_coef        | 0.0391   |
# |    ent_coef_loss   | -5.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12512    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.4     |
# |    ep_rew_mean     | 375      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 108      |
# |    time_elapsed    | 119      |
# |    total_timesteps | 12880    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 40.2     |
# |    ent_coef        | 0.0375   |
# |    ent_coef_loss   | -4.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12779    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.7     |
# |    ep_rew_mean     | 377      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 108      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 13170    |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 39.2     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -5.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13069    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.3     |
# |    ep_rew_mean     | 374      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 108      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 13420    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 47       |
# |    ent_coef        | 0.0353   |
# |    ent_coef_loss   | -7.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13319    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.5     |
# |    ep_rew_mean     | 379      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 108      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 13783    |
# | train/             |          |
# |    actor_loss      | -157     |
# |    critic_loss     | 34.5     |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | -6.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13682    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75       |
# |    ep_rew_mean     | 381      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 108      |
# |    time_elapsed    | 131      |
# |    total_timesteps | 14164    |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 33.4     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | -7.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14063    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.3     |
# |    ep_rew_mean     | 383      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 108      |
# |    time_elapsed    | 134      |
# |    total_timesteps | 14552    |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 44.3     |
# |    ent_coef        | 0.0315   |
# |    ent_coef_loss   | -4.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14451    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.8     |
# |    ep_rew_mean     | 385      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 108      |
# |    time_elapsed    | 137      |
# |    total_timesteps | 14897    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 49.4     |
# |    ent_coef        | 0.0307   |
# |    ent_coef_loss   | -3.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14796    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.3     |
# |    ep_rew_mean     | 388      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 108      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 15236    |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 35.6     |
# |    ent_coef        | 0.03     |
# |    ent_coef_loss   | -6.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15135    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.1     |
# |    ep_rew_mean     | 388      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 108      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 15536    |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 38.7     |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | 3.46     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15435    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.8     |
# |    ep_rew_mean     | 387      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 108      |
# |    time_elapsed    | 146      |
# |    total_timesteps | 15866    |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 43       |
# |    ent_coef        | 0.0293   |
# |    ent_coef_loss   | -1.77    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15765    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.4     |
# |    ep_rew_mean     | 385      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 108      |
# |    time_elapsed    | 149      |
# |    total_timesteps | 16199    |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 35.4     |
# |    ent_coef        | 0.029    |
# |    ent_coef_loss   | -3.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16098    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.9     |
# |    ep_rew_mean     | 387      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 108      |
# |    time_elapsed    | 153      |
# |    total_timesteps | 16558    |
# | train/             |          |
# |    actor_loss      | -159     |
# |    critic_loss     | 31.8     |
# |    ent_coef        | 0.0285   |
# |    ent_coef_loss   | -3.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16457    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.9     |
# |    ep_rew_mean     | 386      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 108      |
# |    time_elapsed    | 156      |
# |    total_timesteps | 16884    |
# | train/             |          |
# |    actor_loss      | -151     |
# |    critic_loss     | 38.8     |
# |    ent_coef        | 0.0284   |
# |    ent_coef_loss   | -0.697   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16783    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.5     |
# |    ep_rew_mean     | 385      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 108      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 17149    |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 42.5     |
# |    ent_coef        | 0.0279   |
# |    ent_coef_loss   | 3.29     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.3     |
# |    ep_rew_mean     | 388      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 107      |
# |    time_elapsed    | 161      |
# |    total_timesteps | 17474    |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 35.2     |
# |    ent_coef        | 0.0278   |
# |    ent_coef_loss   | 2.66     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76       |
# |    ep_rew_mean     | 387      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 107      |
# |    time_elapsed    | 164      |
# |    total_timesteps | 17783    |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.0269   |
# |    ent_coef_loss   | 0.0673   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17682    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.6     |
# |    ep_rew_mean     | 384      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 107      |
# |    time_elapsed    | 166      |
# |    total_timesteps | 18025    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 40.2     |
# |    ent_coef        | 0.0265   |
# ...
# |    fps             | 124      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 86638    |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 28.1     |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86537    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 603      |
# | time/              |          |
# |    episodes        | 1016     |
# |    fps             | 124      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 87210    |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 39.7     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -0.714   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87109    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 602      |
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 124      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 87710    |
# | train/             |          |
# |    actor_loss      | -176     |
# |    critic_loss     | 30.5     |
# |    ent_coef        | 0.0187   |
# |    ent_coef_loss   | -0.554   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87609    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 598      |
# | time/              |          |
# |    episodes        | 1024     |
# |    fps             | 124      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 88120    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 31.9     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -3.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88019    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 604      |
# | time/              |          |
# |    episodes        | 1028     |
# |    fps             | 124      |
# |    time_elapsed    | 108      |
# |    total_timesteps | 88613    |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 28.5     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -5.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88512    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 607      |
# | time/              |          |
# |    episodes        | 1032     |
# |    fps             | 124      |
# |    time_elapsed    | 112      |
# |    total_timesteps | 89058    |
# | train/             |          |
# |    actor_loss      | -165     |
# |    critic_loss     | 30       |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -2.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88957    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 611      |
# | time/              |          |
# |    episodes        | 1036     |
# |    fps             | 125      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 89505    |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 25.9     |
# |    ent_coef        | 0.0191   |
# |    ent_coef_loss   | -1.77    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89404    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 615      |
# | time/              |          |
# |    episodes        | 1040     |
# |    fps             | 125      |
# |    time_elapsed    | 119      |
# |    total_timesteps | 89963    |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 32.1     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -5.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89862    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 612      |
# | time/              |          |
# |    episodes        | 1044     |
# |    fps             | 125      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 90431    |
# | train/             |          |
# |    actor_loss      | -157     |
# |    critic_loss     | 33.6     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | 3.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90330    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 621      |
# | time/              |          |
# |    episodes        | 1048     |
# |    fps             | 125      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 90980    |
# | train/             |          |
# |    actor_loss      | -163     |
# |    critic_loss     | 41.1     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | 2.9      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90879    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | 625      |
# | time/              |          |
# |    episodes        | 1052     |
# |    fps             | 125      |
# |    time_elapsed    | 131      |
# |    total_timesteps | 91491    |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 34.8     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -0.713   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91390    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 617      |
# | time/              |          |
# |    episodes        | 1056     |
# |    fps             | 125      |
# |    time_elapsed    | 134      |
# |    total_timesteps | 91887    |
# | train/             |          |
# |    actor_loss      | -166     |
# |    critic_loss     | 32.6     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91786    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 615      |
# | time/              |          |
# |    episodes        | 1060     |
# |    fps             | 125      |
# |    time_elapsed    | 138      |
# |    total_timesteps | 92353    |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 34.3     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 2.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92252    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 608      |
# | time/              |          |
# |    episodes        | 1064     |
# |    fps             | 125      |
# |    time_elapsed    | 142      |
# |    total_timesteps | 92814    |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 31.1     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | 4.87     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92713    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 605      |
# | time/              |          |
# |    episodes        | 1068     |
# |    fps             | 125      |
# |    time_elapsed    | 145      |
# |    total_timesteps | 93269    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 28.1     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | -3.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93168    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 602      |
# | time/              |          |
# |    episodes        | 1072     |
# |    fps             | 125      |
# |    time_elapsed    | 149      |
# |    total_timesteps | 93746    |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 27.1     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -0.373   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93645    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 603      |
# | time/              |          |
# |    episodes        | 1076     |
# |    fps             | 125      |
# |    time_elapsed    | 153      |
# |    total_timesteps | 94293    |
# | train/             |          |
# |    actor_loss      | -165     |
# |    critic_loss     | 29.2     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | -0.764   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94192    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 604      |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 125      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 94829    |
# | train/             |          |
# |    actor_loss      | -166     |
# |    critic_loss     | 28.7     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | -0.395   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94728    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 604      |
# | time/              |          |
# |    episodes        | 1084     |
# |    fps             | 125      |
# |    time_elapsed    | 161      |
# |    total_timesteps | 95283    |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 28.5     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | 1.55     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95182    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 602      |
# | time/              |          |
# |    episodes        | 1088     |
# |    fps             | 125      |
# |    time_elapsed    | 165      |
# |    total_timesteps | 95779    |
# | train/             |          |
# |    actor_loss      | -166     |
# |    critic_loss     | 27.5     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -2.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95678    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 611      |
# | time/              |          |
# |    episodes        | 1092     |
# |    fps             | 125      |
# |    time_elapsed    | 170      |
# |    total_timesteps | 96413    |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 32.7     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96312    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 608      |
# | time/              |          |
# |    episodes        | 1096     |
# |    fps             | 125      |
# |    time_elapsed    | 174      |
# |    total_timesteps | 96939    |
# | train/             |          |
# |    actor_loss      | -164     |
# |    critic_loss     | 29.3     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | 0.037    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96838    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 615      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 125      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 97473    |
# | train/             |          |
# |    actor_loss      | -177     |
# |    critic_loss     | 38.8     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -1.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97372    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 620      |
# | time/              |          |
# |    episodes        | 1104     |
# |    fps             | 125      |
# |    time_elapsed    | 183      |
# |    total_timesteps | 98077    |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 32.9     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97976    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 618      |
# | time/              |          |
# |    episodes        | 1108     |
# |    fps             | 125      |
# |    time_elapsed    | 187      |
# |    total_timesteps | 98501    |
# | train/             |          |
# |    actor_loss      | -166     |
# |    critic_loss     | 31       |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -2.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 614      |
# | time/              |          |
# |    episodes        | 1112     |
# |    fps             | 125      |
# |    time_elapsed    | 191      |
# |    total_timesteps | 99040    |
# | train/             |          |
# |    actor_loss      | -163     |
# |    critic_loss     | 37.7     |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | -3       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98939    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 610      |
# | time/              |          |
# |    episodes        | 1116     |
# |    fps             | 125      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 99515    |
# | train/             |          |
# |    actor_loss      | -174     |
# |    critic_loss     | 34.6     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | 0.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99414    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 608      |
# | time/              |          |
# |    episodes        | 1120     |
# |    fps             | 125      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 99963    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 36       |
# |    ent_coef        | 0.0191   |
# |    ent_coef_loss   | -2.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99862    |
# ---------------------------------

# %%
gymenv_test = gym.make('Humanoid-v4', render_mode='human')

# %%
test(gymenv_test, 'SAC', 'models/SAC_gamma0_99/100000')
# Out:
# /Users/szymon/miniconda3/envs/IOwADC/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 6.09GB > 4.90GB
#   warnings.warn(

# %%
test(gymenv_test, 'SAC', 'models/SAC_gamma0_9/100000')
# Out:
# /Users/szymon/miniconda3/envs/IOwADC/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 6.09GB > 4.93GB
#   warnings.warn(

# %%
test(gymenv_test, 'SAC', 'models/SAC_gamma0_8/100000')
# Out:
# /Users/szymon/miniconda3/envs/IOwADC/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 6.09GB > 4.90GB
#   warnings.warn(

# %%
test(gymenv_test, 'SAC', 'models/SAC_gamma0_5/100000')
# Out:
# /Users/szymon/miniconda3/envs/IOwADC/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 6.09GB > 4.89GB
#   warnings.warn(

# %%
test(gymenv_test, 'SAC', 'models/SAC_gamma0_1/100000')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
